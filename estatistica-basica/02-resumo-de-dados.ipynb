# %% [markdown]
# <center>
#     <h1>Estastística Básica - Bussab e Morettin</h1>
#     <h2>Capítulo 02 - Resumo de Dados</h2>
# </center>

# %% [markdown]
# ## Resumo
#
# ***
#
# - [Bar Chart, Pie Chart, Frequency Tables | Statistics Tutorial | MarinStatsLectures](https://www.youtube.com/watch?v=Rx8wSEDq5Hs&list=PLqzoL9-eJTNBZDG8jaNuhap1C9q6VHyVa&index=6&ab_channel=MarinStatsLectures-RProgramming%26Statistics)
# - [Histograms and Density Plots for Numeric Variables | Statistics Tutorial | MarinStatsLectures](https://www.youtube.com/watch?v=p-VOptZ0E5Y&list=PLqzoL9-eJTNBZDG8jaNuhap1C9q6VHyVa&index=7&ab_channel=MarinStatsLectures-RProgramming%26Statistics)
#
#
# ***Tipos de variáveis:***
#
# - Variável Qualitativa Nominal: Possíveis realizações são classes sem hierarquia entre si
# - Variável Qualitativa Ordinal: Possíveis realizações são classes com alguma hierarquia entre si
# - Variável Quantitativa Discreta: Uma variável que pertence ao conjunto dos naturais $N$
# - Variável Quantitativa Contínua: Uma variável que pertence ao conjunto dos reais $R$
# - Outras:
#   - *Variável Dummy:* consiste na codificação de uma variável qualitativa como 0 (ausência de um atributo) ou 1 (presença de um certo atributo)
#
# [***Escalas de medida***](https://www.lampada.uerj.br/bioestatisticabasica/introducao.html):
#
# - Escala nominal simples: escala de medida das variáveis qualitativas nominais. Reflete a existência de diferentes classes para o nosso dado.
# - Escala ordinal: escala de medida das variáveis qualitativas ordinais. Reflete a diferentes categorias que possuem uma hierarquia entre si, entretanto, não podemos afirmar que a diferença entre duas categorias é constante ao longo da escala (Exemplo: A primeira classe de um voo é duas vezes melhor que a classe econômica).
#   - Quando há somente duas categorias nessa escala, temos uma *variável dummy*.
# - Escala intervalar: é uma escala numérica onde a diferença entre dois valores possui o mesmo significado ao longo da escala, entretanto, a diferença entre esses dois valores não pode ser expressa como uma razão (ver exemplo do link de referência para melhor compreensão).
# - Escala de razão: semelhantemente a escala intervalar, a escala de razão é numérica e possui a característica de que a diferença entre dois valores possui o mesmo significado ao longo de toda a escala, entretanto, uma vantagem dela é que essa diferença pode ser expressa em como razão, isto é, é possível afirmar que o valor $x$ é o dobro do valor $y$, desde que $\frac{x}{y} = 2$.
#
# ***Gráficos***
#
# - O histograma é uma forma de representar a ***função de densidade de probabilidade*** de uma variável.
#   - O gráfico `kernel density` é uma forma de suavizar o histograma.
# - O ramo-e-folhas é uma alternativa ao histograma, pois há uma menor perda de informação sobre os dados.
# - Gráficos de Pizza 3D enganam a audiência porque a parte 3d dá a impressão de uma área maior para algumas categorias.
#
#
# ***Extras***
#
# - *Função de Distribuição Empírica:* Uma função de distribuição empírica é a função de distribuição associada à medida empírica de uma amostra. Essa função de distribuição cumulativa tem a forma de uma escada e o gráfico dela sintetiza a informação presente em uma tabela de frequência acumulada.

# %% [markdown]
# ## Exemplos
# ***

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# import seabornstyle
plt.style.use('ggplot')

# %%
## Tabela 2.1
tab2_1 = pd.read_csv('dados/tab2_1.csv')
display(tab2_1)
# Out:
#      N estado_civil      grau_instrucao  n_filhos  salario  idade_anos  \
# 0    1     solteiro  ensino fundamental       NaN     4.00          26
# 1    2       casado  ensino fundamental       1.0     4.56          32
# 2    3       casado  ensino fundamental       2.0     5.25          36
# 3    4     solteiro        ensino médio       NaN     5.73          20
# 4    5     solteiro  ensino fundamental       NaN     6.26          40
# 5    6       casado  ensino fundamental       0.0     6.66          28
# 6    7     solteiro  ensino fundamental       NaN     6.86          41
# 7    8     solteiro  ensino fundamental       NaN     7.39          43
# 8    9       casado        ensino médio       1.0     7.59          34
# 9   10     solteiro        ensino médio       NaN     7.44          23
# 10  11       casado        ensino médio       2.0     8.12          33
# 11  12     solteiro  ensino fundamental       NaN     8.46          27
# ...

# %%
## Tabela 2.2

pvt = tab2_1.pivot_table(index='grau_instrucao', values='N', aggfunc='count')
pvt = pvt.assign(proporcao=(pvt['N'] / pvt['N'].sum()), porcentagem=(pvt['N'] / pvt['N'].sum()) * 100)
pvt = pvt.rename(columns={'N': 'frequencia'})
pvt
# Out:
#                     frequencia  proporcao  porcentagem
# grau_instrucao
# ensino fundamental          12   0.333333    33.333333
# ensino médio                18   0.500000    50.000000
# superior                     6   0.166667    16.666667

# %% [markdown]
# ## Exercícios
# ***

# %% [markdown]
# ### Exercício 2.2

# %%
pvt = tab2_1.pivot_table(index='estado_civil', values='N', aggfunc='count')
pvt = pvt.assign(proporcao=(pvt['N'] / pvt['N'].sum()), porcentagem=(pvt['N'] / pvt['N'].sum()) * 100)
pvt = pvt.rename(columns={'N': 'frequencia'})
pvt
# Out:
#               frequencia  proporcao  porcentagem
# estado_civil
# casado                20   0.555556    55.555556
# solteiro              16   0.444444    44.444444

# %%
pvt = tab2_1.pivot_table(index='reg_procedencia', values='N', aggfunc='count')
pvt = pvt.assign(proporcao=(pvt['N'] / pvt['N'].sum()), porcentagem=(pvt['N'] / pvt['N'].sum()) * 100)
pvt = pvt.rename(columns={'N': 'frequencia'})
pvt
# Out:
#                  frequencia  proporcao  porcentagem
# reg_procedencia
# capital                  11   0.305556    30.555556
# interior                 12   0.333333    33.333333
# outra                    13   0.361111    36.111111

# %%
pvt = pd.crosstab(tab2_1['n_filhos'], tab2_1['estado_civil'])
pvt = pvt.assign(frequency=(pvt['casado'] / pvt['casado'].sum()))
pvt
# Out:
# estado_civil  casado  frequency
# n_filhos
# 0.0                4       0.20
# 1.0                5       0.25
# 2.0                7       0.35
# 3.0                3       0.15
# 5.0                1       0.05

# %%
pvt = pd.pivot_table(tab2_1, index='idade_anos', values='N', aggfunc='count')
pvt = pvt.assign(proporcao=(pvt['N'] / pvt['N'].sum()), porcentagem=(pvt['N'] / pvt['N'].sum()) * 100)
pvt = pvt.rename(columns={'N': 'frequencia'})
pvt
# Out:
#             frequencia  proporcao  porcentagem
# idade_anos
# 20                   1   0.027778     2.777778
# 23                   1   0.027778     2.777778
# 25                   1   0.027778     2.777778
# 26                   2   0.055556     5.555556
# 27                   1   0.027778     2.777778
# 28                   1   0.027778     2.777778
# 29                   1   0.027778     2.777778
# 30                   2   0.055556     5.555556
# 31                   2   0.055556     5.555556
# 32                   2   0.055556     5.555556
# 33                   2   0.055556     5.555556
# 34                   2   0.055556     5.555556
# 35                   2   0.055556     5.555556
# 36                   2   0.055556     5.555556
# 37                   2   0.055556     5.555556
# 38                   1   0.027778     2.777778
# 39                   1   0.027778     2.777778
# 40                   2   0.055556     5.555556
# 41                   2   0.055556     5.555556
# ...

# %% [markdown]
# ### Exercício 2.3

# %%
cd_brasil = pd.read_csv('dados/cd_brasil.csv', )
cd_brasil.head()
# Out:
#    Unnamed: 0 regiao  uf  superficie  pop_urbana  pop_rural      total  \
# 0           1  Norte  RO      238513    762864.0   468143.0  1231007.0
# 1           2  Norte  AC      153150    315401.0   168322.0   483726.0
# 2           3  Norte  AM     1577820   1766166.0   623113.0  2389279.0
# 3           4  Norte  RR      225116    174277.0    72854.0   247131.0
# 4           5  Norte  PA     1253165   2949017.0  2561832.0  5510849.0
#
#   densidade
# 0      5,16
# 1      3,16
# 2      1,51
# 3      1,10
# 4      4,40

# %%
cd_brasil = cd_brasil.drop(columns='Unnamed: 0', index=28)
cd_brasil = cd_brasil.assign(densidade=cd_brasil['densidade'].str.replace(',', '.').astype(float))

cd_brasil.head()
# Out:
#   regiao  uf  superficie  pop_urbana  pop_rural      total  densidade
# 0  Norte  RO      238513    762864.0   468143.0  1231007.0       5.16
# 1  Norte  AC      153150    315401.0   168322.0   483726.0       3.16
# 2  Norte  AM     1577820   1766166.0   623113.0  2389279.0       1.51
# 3  Norte  RR      225116    174277.0    72854.0   247131.0       1.10
# 4  Norte  PA     1253165   2949017.0  2561832.0  5510849.0       4.40

# %%
cd_brasil = cd_brasil.assign(bins_pop=pd.cut(cd_brasil['pop_urbana'], 8))

freq_pop = cd_brasil.pivot_table(index='bins_pop', values='uf', aggfunc='count')
freq_pop = freq_pop.assign(freq=(freq_pop['uf'] / freq_pop['uf'].sum()))

freq_pop
# Out:
#                            uf      freq
# bins_pop
# (142682.058, 4123644.75]   19  0.703704
# (4123644.75, 8073012.5]     5  0.185185
# (8073012.5, 12022380.25]    0  0.000000
# (12022380.25, 15971748.0]   2  0.074074
# (15971748.0, 19921115.75]   0  0.000000
# (19921115.75, 23870483.5]   0  0.000000
# (23870483.5, 27819851.25]   0  0.000000
# (27819851.25, 31769219.0]   1  0.037037

# %%
cd_brasil = cd_brasil.assign(bins_densidade=pd.cut(cd_brasil['densidade'], 8))

freq_densidade = cd_brasil.pivot_table(index='bins_densidade', values='uf', aggfunc='count')
freq_densidade = freq_densidade.assign(freq=(freq_densidade['uf'] / freq_densidade['uf'].sum()))

freq_densidade
# Out:
#                      uf      freq
# bins_densidade
# (-0.222, 166.338]    24  0.888889
# (166.338, 331.575]    2  0.074074
# (331.575, 496.813]    0  0.000000
# (496.813, 662.05]     0  0.000000
# (662.05, 827.288]     0  0.000000
# (827.288, 992.525]    0  0.000000
# (992.525, 1157.762]   0  0.000000
# (1157.762, 1323.0]    1  0.037037

# %% [markdown]
# ### Exercício 2.4

# %%
dias = [i for i in range(1, 51)]
erros = [
    8, 11, 8, 12, 14, 13, 11, 14, 14, 15,
    6, 10, 14, 19, 6, 12, 7, 5, 8, 8,
    10, 16, 10, 12, 12, 8, 11, 6, 7, 12,
    7, 10, 14, 5, 12, 7, 9, 12, 11, 9,
    14, 8, 14, 8, 12, 10, 12, 22, 7, 15,
]

# %%
sns.histplot(erros, stat='frequency')
plt.show()

# %%
stems = [int(str(i)[0]) for i in erros]
plt.stem(stems, erros, orientation='horizontal')
plt.show()

# %% [markdown]
# ### Exercício 2.5

# %%
tab2_1 = pd.read_csv('dados/tab2_1.csv')
tab2_1.head()
# Out:
#    N estado_civil      grau_instrucao  n_filhos  salario  idade_anos  \
# 0  1     solteiro  ensino fundamental       NaN     4.00          26
# 1  2       casado  ensino fundamental       1.0     4.56          32
# 2  3       casado  ensino fundamental       2.0     5.25          36
# 3  4     solteiro        ensino médio       NaN     5.73          20
# 4  5     solteiro  ensino fundamental       NaN     6.26          40
#
#    idade_meses reg_procedencia
# 0            3        interior
# 1           10         capital
# 2            5         capital
# 3           10           outra
# 4            7           outra

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 7))

sns.histplot(data=tab2_1, x='idade_anos', stat='count', binwidth=5, ax=axes[0])
sns.histplot(data=tab2_1, x='idade_anos', stat='percent', binwidth=5, ax=axes[1])

plt.show()

# %%
sns.histplot(data=tab2_1, x='grau_instrucao', stat='count')
plt.show()

# %% [markdown]
# ### Exercício 2.6

# %%
cresc_anual = [
    3.67, 1.82, 3.73, 4.10, 4.30,
    1.28, 8.14, 2.43, 4.17, 5.63,
    3.96, 6.54, 5.84, 7.35, 3.63,
    2.93, 2.82, 8.45, 5.28, 5.41,
    7.77, 4.65, 1.88, 2.12, 4.26,
    2.78, 5.54, 0.90, 5.09, 4.07
]
# bins = [str(i) for i in pd.cut(cresc_anual, 6)]
# http://seaborn.pydata.org/generated/seaborn.stripplot.html?highlight=stripplot#seaborn.stripplot

sns.histplot(cresc_anual, binwidth=1, stat='percent')

plt.show()

# %% [markdown]
# ### Exercício 2.7

# %%
df = pd.read_csv('dados/tab2_1.csv')

instrucao = df.pivot_table(index='grau_instrucao', values='N', aggfunc='count')

salario = df.assign(bins_salario=pd.cut(df['salario'], 4))
salario = salario.pivot_table(index='bins_salario', values='N', aggfunc='count')

display(instrucao)
display(salario)
# Out:
#                      N
# grau_instrucao
# ensino fundamental  12
# ensino médio        18
# superior             6
#                   N
# bins_salario
# (3.981, 8.825]   13
# (8.825, 13.65]   13
# (13.65, 18.475]   7
# (18.475, 23.3]    3

# %% [markdown]
# Analisando as outras tabelas dispostas no livro, eu escolheria chefiar a seção técnica da empresa, pois mais pessoas para liderar representa um desafio maior.

# %% [markdown]
# ### Exercício 2.8

# %%
df = pd.read_csv('dados/cd_municipios.csv', usecols=[1, 2, 3])

display(df.head())
print(df.shape)
# Out:
#    n           municipio  populacao
# 0  1       São Paulo(SP)      988.8
# 1  2  Rio de Janeiro(RJ)      556.9
# 2  3        Salvador(BA)      224.6
# 3  4  Belo Horizonte(MG)      210.9
# 4  5       Fortaleza(CE)      201.5
# (30, 3)

# %%
sns.histplot(data=df, x='populacao', binwidth=100, stat='count')
plt.show()

# %%
sns.swarmplot(data=df, x='populacao', native_scale=True)
plt.show()

# %% [markdown]
# ### Exercício 2.9

# %%
df = pd.DataFrame(
    dict(
        SECAO=[
            "P", "P", "P", "P", "P", "P", "P", "T", "T", "T", "T", "T", "T", "T", "V", "V", "V", "V", "V", "V", "V", "V", "V", "V", "V",
        ],
        ADM=[
            8, 8, 8, 6, 8, 8, 8, 10, 8, 10, 8, 8, 6, 10, 8, 8, 8, 6, 6, 6, 8, 6, 8, 8, 8,
        ],
        Direito=[
            9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9,
        ],
        Redacao=[
            8.6, 7, 8, 8.6, 8, 8.5, 8.2, 7.5, 9.4, 7.9, 8.6, 8.3, 7, 8.6, 8.6, 9.5, 6.3, 7.6, 6.8, 7.5, 7.7, 8.7, 7.3, 8.5, 7,
        ],
        Estatistica=[
            9, 9, 8, 8, 9, 10, 8, 8, 9, 8, 10, 7, 7, 9, 9, 7, 8, 9, 4, 7, 7, 8, 10, 9, 9,
        ],
        Ingles=[
            "B", "B", "D", "D", "A", "B", "D", "B", "B", "B", "C", "D", "B", "A", "C", "A", "D", "C", "D", "C", "D", "C", "C", "A", "B",
        ],
        Metodologia=[
            "A", "C", "B", "C", "A", "A", "C", "C", "B", "C", "B", "B", "C", "B", "B", "A", "C", "C", "C", "B", "B", "A", "C", "A", "A",
        ],
        Politica=[
            9, 6.5, 9, 6, 6.5, 6.5, 9, 6, 10, 9, 10, 6.5, 6, 10, 10, 9, 10, 6, 6, 6, 6.5, 6, 9, 6.5, 9,
        ],
        Economia=[
            8.5, 8, 8.5, 8.5, 9, 9.5, 7, 8.5, 8, 7.5, 8.5, 8, 8.5, 7.5, 7, 7.5, 7.5, 8.5, 9.5, 8.5, 8, 9, 7, 9, 8.5,
        ],
    )
)

df
# Out:
#    SECAO  ADM  Direito  Redacao  Estatistica Ingles Metodologia  Politica  \
# 0      P    8        9      8.6            9      B           A       9.0
# 1      P    8        9      7.0            9      B           C       6.5
# 2      P    8        9      8.0            8      D           B       9.0
# 3      P    6        9      8.6            8      D           C       6.0
# 4      P    8        9      8.0            9      A           A       6.5
# 5      P    8        9      8.5           10      B           A       6.5
# 6      P    8        9      8.2            8      D           C       9.0
# 7      T   10        9      7.5            8      B           C       6.0
# 8      T    8        9      9.4            9      B           B      10.0
# 9      T   10        9      7.9            8      B           C       9.0
# 10     T    8        9      8.6           10      C           B      10.0
# 11     T    8        9      8.3            7      D           B       6.5
# ...

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

# Direito, Politica, Estatistica, Redacao

sns.swarmplot(data=df, x="Direito", ax=axes[0])

sns.kdeplot(data=df, x="Politica", bw_adjust=.5, ax=axes[1])
sns.kdeplot(data=df, x="Estatistica", bw_adjust=.5, ax=axes[2])
sns.histplot(data=df, x="Redacao", ax=axes[3])

plt.show()
# Out:
# <AxesSubplot: xlabel='Redacao', ylabel='Count'>

# %% [markdown]
# A variável "Direito" possui variância zero, ou seja, todas as observações assumem o mesmo valor. As outras variáveis não possuem uma distribuição simétrica, mas a diferença entre elas é que a variável "Política" chega bem próxima de ser bimodal, enquanto as outras duas apresentam assimetria à esquerda.

# %%
sns.swarmplot(data=df, x="Metodologia")

plt.show()

# %%
sns.boxplot(data=df, x="SECAO", y="Estatistica", showmeans=True)

plt.show()

# %% [markdown]
# Como é possível ver no gráfico acima, a média e mediana de todas as seções são bem próximas, entretanto, o gráfico indica que a seção P possui um desempenho melhor do que as outras seções, dado que a amplitude interquartil é menor e a média geral das notas é maior. Seguindo esse raciocínio, vemos que a seção V é a que possui o pior desempenho.

# %% [markdown]
# ### Exercício 2.10

# %%
df = pd.DataFrame({"aluguel": ["2 a 3", "3 a 5", "5 a 7", "7 a 10", "10 a 15"],
                   "zona urbana": [10, 40, 80, 50, 20],
                   "zona rural": [30, 50, 15, 5, 0]})

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 7))

z_urbana = list()
[z_urbana.extend(k) for k in [[i,] * x for i, x in zip(df["aluguel"], df["zona urbana"])]]

z_rural = list()
[z_rural.extend(k) for k in [[i,] * x for i, x in zip(df["aluguel"], df["zona rural"])]]

sns.histplot(x=z_urbana, stat="frequency", ax=axes[0])
sns.histplot(x=z_rural, stat="frequency", ax=axes[1])
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# ### Exercício 2.13

# %%
tab2_1 = pd.read_csv('dados/tab2_1.csv')
tab2_1.head()
# Out:
#    N estado_civil      grau_instrucao  n_filhos  salario  idade_anos  \
# 0  1     solteiro  ensino fundamental       NaN     4.00          26
# 1  2       casado  ensino fundamental       1.0     4.56          32
# 2  3       casado  ensino fundamental       2.0     5.25          36
# 3  4     solteiro        ensino médio       NaN     5.73          20
# 4  5     solteiro  ensino fundamental       NaN     6.26          40
#
#    idade_meses reg_procedencia
# 0            3        interior
# 1           10         capital
# 2            5         capital
# 3           10           outra
# 4            7           outra

# %%
df = tab2_1.assign(idades=pd.cut(tab2_1['idade_anos'], [20, 25, 30, 35, 40, 45, 50], right=False))

frequencias = df.pivot_table(index='idades', values='N', aggfunc='count').reset_index()
frequencias = frequencias.assign(freq=frequencias["N"] / frequencias["N"].sum(), 
                                 freq_acumulada= frequencias["N"].cumsum() / frequencias["N"].sum())
frequencias
# Out:
#      idades   N      freq  freq_acumulada
# 0  [20, 25)   2  0.055556        0.055556
# 1  [25, 30)   6  0.166667        0.222222
# 2  [30, 35)  10  0.277778        0.500000
# 3  [35, 40)   8  0.222222        0.722222
# 4  [40, 45)   8  0.222222        0.944444
# 5  [45, 50)   2  0.055556        1.000000

# %%
tab2_1["idade_anos"].hist(cumulative=True, density=1, bins=6, histtype='step')
# Out:
# <AxesSubplot: >
