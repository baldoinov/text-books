# %%
data = load("dados/dados.RData", verbose=TRUE)
# Out:
# Loading objects:
#   inflacao_Y
#   RC_
#   x
#   tab16_9A
#   teste_quiquad
#   err_pad
#   fdamvnorm
#   reg_resist
#   tab16_5
#   age
#   tab16_6
#   tab16_8
#   dados.ex14_6
#   moda2
#   ano
#   mean_sexo
#   .First
#   mean_idade
#   tab6_13
#   rbernoulli
#   dados.tab4_14
#   teste_t
#   np_k
#   e1
#   e2
#   MV
#   e3
#   tab14_10
#   p.test
#   varp
#   q_i
#   IC_proporcoes
#   moda
#   test_tab14_2
#   test_tab14_5
#   IC_t
#   munic
#   cd_municipios
#   IC
#   dados.ex4_4
#   scatter.marginal
#   c_hum
#   dados.ex4_6
#   tab4_18
#   tab14_2
#   tab14_5
#   dureza
#   dm
#   cd_notas
#   sex
#   tab14_8
#   cd_brasil
#   c_bio
#   n_k
#   dados.tab4_7
#   dados.tab4_8
#   cd_temperaturas
#   anos_exp
#   IC_t_diff
#   scdf
#   .Random.seed
#   n_clientes
#   cd_veiculos
#   cd_mercado
#   RC
#   tab15_1
#   tab15_4
#   .Last
#   tab2_1
#   teste_var
#   summary2
#   acidentes
#   cd_poluicao
#   IC_diff_medias

# %%
cd_brasil
# Out:
#    regiao       uf       superficie pop_urbana pop_rural total    densidade
# 1  Norte        RO        238513      762864    468143    1231007 5,16
# 2  Norte        AC        153150      315401    168322     483726 3,16
# 3  Norte        AM       1577820     1766166    623113    2389279 1,51
# 4  Norte        RR        225116      174277     72854     247131 1,10
# 5  Norte        PA       1253165     2949017   2561832    5510849 4,40
# 6  Norte        AP        143454      330590     48869     379459 2,65
# 7  Norte        TO        278421      741009    307633    1048642 3,77
# 8  Nordeste     MA        333366     2711557   2511008    5222565 15,67
# 9  Nordeste     PI        252379     1556115   1117061    2673176 10,59
# 10 Nordeste     Litígio*    2977          NA        NA         NA
# 11 Nordeste     CE        146348     4713311   2096483    6809794 46,53
# 12 Nordeste     RN         53307     1843486    715174    2558660 48,00
# ...
