# %%
data = load("dados/dados.RData", verbose=TRUE)
# Out:
# Loading objects:
#   inflacao_Y
#   RC_
#   x
#   tab16_9A
#   teste_quiquad
#   err_pad
#   fdamvnorm
#   reg_resist
#   tab16_5
#   age
#   tab16_6
#   tab16_8
#   dados.ex14_6
#   moda2
#   ano
#   mean_sexo
#   .First
#   mean_idade
#   tab6_13
#   rbernoulli
#   dados.tab4_14
#   teste_t
#   np_k
#   e1
#   e2
#   MV
#   e3
#   tab14_10
#   p.test
#   varp
#   q_i
#   IC_proporcoes
#   moda
#   test_tab14_2
#   test_tab14_5
#   IC_t
#   munic
#   cd_municipios
#   IC
#   dados.ex4_4
#   scatter.marginal
#   c_hum
#   dados.ex4_6
#   tab4_18
#   tab14_2
#   tab14_5
#   dureza
#   dm
#   cd_notas
#   sex
#   tab14_8
#   cd_brasil
#   c_bio
#   n_k
#   dados.tab4_7
#   dados.tab4_8
#   cd_temperaturas
#   anos_exp
#   IC_t_diff
#   scdf
#   .Random.seed
#   n_clientes
#   cd_veiculos
#   cd_mercado
#   RC
#   tab15_1
#   tab15_4
#   .Last
#   tab2_1
#   teste_var
#   summary2
#   acidentes
#   cd_poluicao
#   IC_diff_medias

# %%
tab2_1
# Out:
#    N  estado_civil grau_instrucao     n_filhos salario idade_anos idade_meses
# 1   1 solteiro     ensino fundamental NA        4.00   26          3
# 2   2 casado       ensino fundamental  1        4.56   32         10
# 3   3 casado       ensino fundamental  2        5.25   36          5
# 4   4 solteiro     ensino médio       NA        5.73   20         10
# 5   5 solteiro     ensino fundamental NA        6.26   40          7
# 6   6 casado       ensino fundamental  0        6.66   28          0
# 7   7 solteiro     ensino fundamental NA        6.86   41          0
# 8   8 solteiro     ensino fundamental NA        7.39   43          4
# 9   9 casado       ensino médio        1        7.59   34         10
# 10 10 solteiro     ensino médio       NA        7.44   23          6
# 11 11 casado       ensino médio        2        8.12   33          6
# 12 12 solteiro     ensino fundamental NA        8.46   27         11
# ...
